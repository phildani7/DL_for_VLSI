# %% [markdown]
# Advantages of Python:
# 1. Easy to learn
# 2. Felxibility
# 3. Libraries
# 4. Community support
# 5. ChatGPT / https://claude.ai/
# 6. Automate

# %%
x = 5
x = 3.5

# %%
x
# Out:
# 3.5

# %%
name = "Phil"

# %%
if x > 0:
  print("x is positive")
  print("again, x is positive")
else:
  print("x is negative")
# Out:
# x is positive
# again, x is positive

# %%
for i in range(5):
  print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
def greet(name):
  return "Hello, "+ name + " !"

xyz = greet("phil")
print(xyz)
# Out:
# Hello, phil !

# %%
#List
#Mutable - change
#orderered
#indexing & slcicing

fruits = ["apple", "banana", "cherry"]

fruits[1]
# Out:
# 'banana'

# %%
fruits.append("orange")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits.remove("banana")

# %%
print(fruits)
print(fruits[0])
# Out:
# ['apple', 'cherry', 'orange']
# apple

# %%
fruits.append("banana")

# %%
fruits
# Out:
# ['apple', 'cherry', 'orange', 'banana']

# %%
fruits[1:3]
# Out:
# ['cherry', 'orange']

# %%
fruits[-1]
# Out:
# 'banana'

# %%
#Dictionary
#key->value pairs
#Mutable - change
#unorderered
#key = unique

person ={"name":"phil", "age": 25, "city": "Hamirpur"}

person["age"]
# Out:
# 25

# %%
person["email"]= "phildani7@nith.ac.in"

# %%
person
# Out:
# {'name': 'phil',
#  'age': 25,
#  'city': 'Hamirpur',
#  'email': 'phildani7@nith.ac.in'}

# %%
del person["age"]

# %%
person
# Out:
# {'name': 'phil', 'city': 'Hamirpur', 'email': 'phildani7@nith.ac.in'}

# %%
#String
#Immutable - cannot change
#orderered
#indexing & sclicing

greeting = "Welcome to NIT Hamirpur"

# %%
greeting[0]
# Out:
# 'W'

# %%
greeting[11:14]
# Out:
# 'NIT'

# %%
#Tuples
#Immutable - cannot change
#orderered
#indexing & slcicing

fruits = ("banana", "cherry", "onion")

# %%
#Numpy


import numpy as np

new_np_array = np.array([[1,2,3],[4,5,6]])
#[[1,2,3],
# [4,5,6]]

# %%
new_np_array[0,1]
# Out:
# 2

# %%
new_np_array[0, :]
# Out:
# array([1, 2, 3])

# %%
#numpy - applies math to all elements in one go

np.square(new_np_array)
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %%
new_np_array+2 #broadcasting
# Out:
# array([[3, 4, 5],
#        [6, 7, 8]])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

C = np.dot(A, B)

# %%
C
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
import time

size = 1000000
python_list = list(range(size))

# %%
python_list

# %%
numpy_array = np.array(size)

# %%
start = time.time()
python_result = [x * 2 for x in python_list]
python_time = time.time() - start

# %%
start = time.time()
numpy_array_result = numpy_array * 2
numpy_time = time.time() - start

# %%
python_time
# Out:
# 0.08817243576049805

# %%
numpy_time
# Out:
# 0.00016355514526367188

# %%
#Numerical functions

a = np.array([[3, 2, -1], [2, -2, 4], [-1, 0.5, -1]]) #coefficients
b = np.array([1, -2, 0])#constants

x,y,z =np.linalg.solve(a,b)

# %%
x,y,z
# Out:
# (0.9999999999999994, -1.9999999999999984, -1.9999999999999984)

# %%
data = np.array([1, 3, 6, 7, 44, 65, 43, 56, 78])

# %%
mean = np.mean(data)

# %%
mean
# Out:
# 33.666666666666664

# %%
np.median(data)
# Out:
# 43.0

# %%
np.std(data)
# Out:
# 28.134597128012256

# %%
#DFT

t = np.linspace(0, 1, 500)
signal = np.sin(2 * np.pi * 60 * t) + np.sin(2 * np.pi * 120 * t)

freq_spec = np.fft.fft(signal)

# %%
freq_spec

# %%
from scipy.integrate import odeint

def model(y, x):
    return x + y

y0 = 0

x = np.linspace(0, 5, 100)

# %%
y = odeint(model, y0, x)

# %%
y

# %%
#PLOT

import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x ,y)
plt.title("Sine wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %%
#scatter plot

import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y)
plt.title("Random Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data, bins=30)
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("Frequency")
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 5]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [20, 25, 35, 10]

plt.pie(values, labels=categories, autopct='%1.1f%%')
plt.title("Pie Chart Example")
plt.show()

# %%
#Signal processing example

from scipy.signal import butter, lfilter

def lowpass_filter(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    filtered_data = lfilter(b, a, data)
    return filtered_data

# Sample data
data = np.sin(2 * np.pi * 1.2 * np.linspace(0, 1, 100)) + np.random.randn(100) * 0.2

# Apply filter
filtered_data = lowpass_filter(data, cutoff=0.5, fs=10)

# Plot
plt.plot(data, label='Noisy Signal')
plt.plot(filtered_data, label='Filtered Signal')
plt.legend()
plt.show()

# %%
from scipy.signal import convolve

# Define two signals
signal = np.array([1, 2, 3])
impulse_response = np.array([0, 1, 0.5])

# Convolution
convolved_signal = convolve(signal, impulse_response)

# Plot
plt.stem(convolved_signal)
plt.title("Convolved Signal")
plt.show()

# %%
from scipy.signal import spectrogram

# Generate a signal
fs = 10e3
N = 1e5
amp = 2 * np.sqrt(2)
freq = 1234.0
noise_power = 0.001 * fs / 2
time = np.arange(N) / fs
signal = amp * np.sin(2 * np.pi * freq * time)
signal += np.random.normal(scale=np.sqrt(noise_power), size=time.shape)

# Compute and plot the spectrogram
frequencies, times, Sxx = spectrogram(signal, fs)
plt.pcolormesh(times, frequencies, 10 * np.log10(Sxx))
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.title("Spectrogram")
plt.show()

# %%
from scipy.signal import sawtooth

t=np.linspace(0,1,500)
wave = sawtooth(2 *np.pi*5*t)
plt.plot(t, wave)
plt.ylabel('Sawtooth Waveform')
plt.xlabel('Time')
plt.title("Amplitude")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

g = 9.81  # Gravity constant
v0 = 20   # Initial velocity (m/s)
angle = 45  # Launch angle in degrees

# Time of flight calculation
t_flight = (2 * v0 * np.sin(np.radians(angle))) / g

# Time intervals
t = np.linspace(0, t_flight, num=100)

# X and Y coordinates
x = v0 * t * np.cos(np.radians(angle))
y = v0 * t * np.sin(np.radians(angle)) - 0.5 * g * t**2

plt.plot(x, y)
plt.title("Projectile Motion")
plt.xlabel("Distance (m)")
plt.ylabel("Height (m)")
plt.show()

# %%
# !pip install molmass
from molmass import Formula

# Molecular formula
f = Formula("C6H12O6")  # Glucose

# Calculate and print molecular weight
print("Molecular Weight:", f.mass)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 1.8 MB/s eta 0:00:00
# ...
# Molecular Weight: 180.156162

# %%
import numpy as np
import matplotlib.pyplot as plt

# SIR model parameters
beta, gamma = 0.3, 0.1
S, I, R = 0.99, 0.01, 0.0

# Simulation over 100 days
for _ in range(100):
    new_infections = beta * S * I
    new_recoveries = gamma * I
    S, I, R = S - new_infections, I + new_infections - new_recoveries, R + new_recoveries

# Plotting the results
plt.plot(S, label='Susceptible')
plt.plot(I, label='Infected')
plt.plot(R, label='Recovered')
plt.legend()
plt.show()
