# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt


# Load the MNIST data
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize and reshape the data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.expand_dims(x_train, axis=-1)  # Reshape to (28, 28, 1)
x_test = np.expand_dims(x_test, axis=-1)    # Reshape to (28, 28, 1)

# Input placeholder
input_img = Input(shape=(28, 28, 1))

# Encoder
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# Decoder
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Autoencoder model
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Display the model architecture
autoencoder.summary()

# Train the autoencoder
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))

# After training, you can use the autoencoder to encode and decode images from the test set
decoded_imgs = autoencoder.predict(x_test)

# Use Matplotlib to visualize the results
n = 10  # Number of digits to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.axis('off')

    # Display reconstruction
    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.axis('off')

plt.shozw()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 8)           0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 8)           0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 8)           0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_2 (UpSamplin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4385 (17.13 KB)
# Trainable params: 4385 (17.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 18s 8ms/step - loss: 0.2155 - val_loss: 0.1460
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1340 - val_loss: 0.1242
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1214 - val_loss: 0.1165
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1156 - val_loss: 0.1123
# Epoch 5/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1118 - val_loss: 0.1095
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1092 - val_loss: 0.1068
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1071 - val_loss: 0.1053
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1055 - val_loss: 0.1035
# Epoch 9/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1041 - val_loss: 0.1023
# Epoch 10/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1030 - val_loss: 0.1014
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1020 - val_loss: 0.1001
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1011 - val_loss: 0.0997
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1004 - val_loss: 0.0988
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0997 - val_loss: 0.0985
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0991 - val_loss: 0.0980
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0986 - val_loss: 0.0971
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0981 - val_loss: 0.0968
# Epoch 18/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0976 - val_loss: 0.0963
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0972 - val_loss: 0.0958
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0969 - val_loss: 0.0954
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0965 - val_loss: 0.0953
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0961 - val_loss: 0.0950
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0959 - val_loss: 0.0949
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0956 - val_loss: 0.0945
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0939
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0951 - val_loss: 0.0939
# Epoch 27/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0948 - val_loss: 0.0938
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0939
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0944 - val_loss: 0.0931
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0930
# Epoch 31/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0942 - val_loss: 0.0930
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0928
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0927
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0924
# Epoch 36/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0929 - val_loss: 0.0923
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0913
# Epoch 45/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0925 - val_loss: 0.0914
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0924 - val_loss: 0.0912
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0912
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0922 - val_loss: 0.0913
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0922 - val_loss: 0.0913
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0920 - val_loss: 0.0910
# 313/313 [==============================] - 1s 2ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4e04a56a1b85> in <cell line: 70>()
#      68     ax.axis('off')
#      69
# ---> 70 plt.shozw()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shozw'
