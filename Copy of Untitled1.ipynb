# %%
# for reproducibility
from numpy.random import seed
seed(1)
#from tensorflow import set_random_seedset_random_seed
#set_random_seed(1)

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Flatten
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)
Y_train = np_utils.to_categorical(Y_train, 10)
Y_test = np_utils.to_categorical(Y_test, 10)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model = Sequential
model.add = Convolution2D(filters=32, kernel_size=(3, 3), input_shape=(28, 28, 1))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 15:47:53.281667 139851760215936 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
