# %%
prime=0
total=0
for number in range(2,31):
  for i in range(2,number):
    if(number%i==0):
      prime=0
      break
    else:
      prime=1
  if(prime):
    total=total+number
print(total)
# Out:
# 127

# %%
c=0
c+=7

# %%
c
# Out:
# 7
