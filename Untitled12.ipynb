# %%
import plotly.graph_objects as go

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = labels,
      color = colors
    ),
    link = dict(
      source = [labels.index(s) for s in source],  # indices of source nodes
      target = [labels.index(t) for t in target],  # indices of target nodes
      value = values
    ))])

fig.update_layout(title_text="Change in Suicide Rates from 2000 to 2023 for Top 20 Countries", font_size=10)
fig.show()
# Out:
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
