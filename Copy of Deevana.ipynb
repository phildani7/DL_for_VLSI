# %%
import pandas as pd

# Assuming the data is in a list of dictionaries, where each dictionary represents a row
data = [
    {'Issue': 'Context1', 'Department 1': 10, 'Department 2': 10, 'Department 3': 10, 'Department 4': 2.5, 'Department 5': 10, 'Department 6': 10},
    {'Issue': 'Context2', 'Department 1': 5, 'Department 2': 5, 'Department 3': 2.5, 'Department 4': 5, 'Department 5': 5, 'Department 6': 5},
    {'Issue': 'Context3', 'Department 1': 5, 'Department 2': 5, 'Department 3': 5, 'Department 4': 7.5, 'Department 5': 5, 'Department 6': 7.5},
    {'Issue': 'Context4', 'Department 1': 5, 'Department 2': 2.5, 'Department 3': 2.5, 'Department 4': 7.5, 'Department 5': 7.5, 'Department 6': 5},
    {'Issue': 'Context5', 'Department 1': 7.5, 'Department 2': 7.5, 'Department 3': 7.5, 'Department 4': 7.5, 'Department 5': 2.5, 'Department 6': 7.5},
    {'Issue': 'Context6', 'Department 1': 10, 'Department 2': 10, 'Department 3': 5, 'Department 4': 7.5, 'Department 5': 7.5, 'Department 6': 7.5},
    # Add the rest of the data rows here
]

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Drop the 'Issue' column as it's not needed for correlation calculation
df.drop(columns=['Issue'], inplace=True)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#               Department 1  Department 2  Department 3  Department 4  \
# Department 1      1.000000      0.951817      0.725018     -0.364698
# Department 2      0.951817      1.000000      0.753411     -0.394771
# Department 3      0.725018      0.753411      1.000000     -0.511199
# Department 4     -0.364698     -0.394771     -0.511199      1.000000
# Department 5      0.484881      0.314918      0.244677     -0.569803
# Department 6      0.765641      0.804400      0.946943     -0.476331
#
#               Department 5  Department 6
# Department 1      0.484881      0.765641
# Department 2      0.314918      0.804400
# Department 3      0.244677      0.946943
# Department 4     -0.569803     -0.476331
# Department 5      1.000000      0.379980
# Department 6      0.379980      1.000000
