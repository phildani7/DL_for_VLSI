# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt


# Load the MNIST data
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize and reshape the data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.expand_dims(x_train, axis=-1)  # Reshape to (28, 28, 1)
x_test = np.expand_dims(x_test, axis=-1)    # Reshape to (28, 28, 1)

# Input placeholder
input_img = Input(shape=(28, 28, 1))

# Encoder
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# Decoder
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Autoencoder model
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Display the model architecture
autoencoder.summary()

# Train the autoencoder
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))

# After training, you can use the autoencoder to encode and decode images from the test set
decoded_imgs = autoencoder.predict(x_test)

# Use Matplotlib to visualize the results
n = 10  # Number of digits to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.axis('off')

    # Display reconstruction
    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.axis('off')

plt.shozw()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 8)           0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 8)           0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 8)           0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_2 (UpSamplin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4385 (17.13 KB)
# Trainable params: 4385 (17.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 66s 137ms/step - loss: 0.2105 - val_loss: 0.1457
# Epoch 2/50
# 469/469 [==============================] - 61s 131ms/step - loss: 0.1351 - val_loss: 0.1262
# Epoch 3/50
# 469/469 [==============================] - 60s 127ms/step - loss: 0.1233 - val_loss: 0.1184
# Epoch 4/50
# 469/469 [==============================] - 62s 132ms/step - loss: 0.1174 - val_loss: 0.1138
# Epoch 5/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1134 - val_loss: 0.1104
# Epoch 6/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1105 - val_loss: 0.1080
# Epoch 7/50
# 469/469 [==============================] - 63s 134ms/step - loss: 0.1084 - val_loss: 0.1059
# Epoch 8/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.1066 - val_loss: 0.1045
# Epoch 9/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.1053 - val_loss: 0.1034
# Epoch 10/50
# 469/469 [==============================] - 61s 129ms/step - loss: 0.1041 - val_loss: 0.1024
# Epoch 11/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1032 - val_loss: 0.1020
# Epoch 12/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.1024 - val_loss: 0.1006
# Epoch 13/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.1016 - val_loss: 0.1001
# Epoch 14/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.1011 - val_loss: 0.0996
# Epoch 15/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.1005 - val_loss: 0.0993
# Epoch 16/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1000 - val_loss: 0.0984
# Epoch 17/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0995 - val_loss: 0.0979
# Epoch 18/50
# 469/469 [==============================] - 60s 129ms/step - loss: 0.0991 - val_loss: 0.0980
# Epoch 19/50
# 469/469 [==============================] - 61s 129ms/step - loss: 0.0987 - val_loss: 0.0973
# Epoch 20/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0983 - val_loss: 0.0970
# Epoch 21/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0980 - val_loss: 0.0980
# Epoch 22/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0977 - val_loss: 0.0963
# Epoch 23/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0974 - val_loss: 0.0961
# Epoch 24/50
# 469/469 [==============================] - 57s 123ms/step - loss: 0.0971 - val_loss: 0.0958
# Epoch 25/50
# 469/469 [==============================] - 60s 127ms/step - loss: 0.0969 - val_loss: 0.0955
# Epoch 26/50
# 469/469 [==============================] - 59s 125ms/step - loss: 0.0966 - val_loss: 0.0954
# Epoch 27/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0964 - val_loss: 0.0951
# Epoch 28/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0961 - val_loss: 0.0951
# Epoch 29/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0959 - val_loss: 0.0951
# Epoch 30/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0957 - val_loss: 0.0947
# Epoch 31/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0955 - val_loss: 0.0942
# Epoch 32/50
# 469/469 [==============================] - 59s 125ms/step - loss: 0.0954 - val_loss: 0.0941
# Epoch 33/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.0952 - val_loss: 0.0941
# Epoch 34/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0950 - val_loss: 0.0938
# Epoch 35/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.0948 - val_loss: 0.0940
# Epoch 36/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0947 - val_loss: 0.0935
# Epoch 37/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0945 - val_loss: 0.0934
# Epoch 38/50
# 469/469 [==============================] - 59s 125ms/step - loss: 0.0944 - val_loss: 0.0933
# Epoch 39/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0942 - val_loss: 0.0932
# Epoch 40/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0941 - val_loss: 0.0928
# Epoch 41/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 42/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0939 - val_loss: 0.0931
# Epoch 43/50
# 469/469 [==============================] - 61s 130ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 44/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0937 - val_loss: 0.0933
# Epoch 45/50
# 469/469 [==============================] - 59s 127ms/step - loss: 0.0936 - val_loss: 0.0922
# Epoch 46/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 47/50
# 469/469 [==============================] - 58s 123ms/step - loss: 0.0934 - val_loss: 0.0923
# Epoch 48/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0932 - val_loss: 0.0923
# Epoch 49/50
# 469/469 [==============================] - 58s 124ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 50/50
# 469/469 [==============================] - 60s 127ms/step - loss: 0.0931 - val_loss: 0.0925
# 313/313 [==============================] - 3s 9ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fb2df3e52665> in <cell line: 55>()
#      53 # Use Matplotlib to visualize the results
#      54 n = 10  # Number of digits to display
# ---> 55 plt.figure(figsize=(20, 4))
#      56 for i in range(n):
#      57     # Display original
#
# NameError: name 'plt' is not defined
