# %%
import numpy as np

# %%
np.random.seed(35)

# %%
import keras

# %%
from keras.datasets import mnist

# %%
(X_train, Y_train),(X_test, Y_test)= mnist.load_data()

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
from keras.optimizers import SGD

# %%
import matplotlib.pyplot as plt

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
Y_train.shape
# Out:
# (60000,)

# %%
plt.gray
# Out:
# <function matplotlib.pyplot.gray>

# %%
plt.imshow(X_train[0])

# %%
Y_train[0]
# Out:
# 5

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train = X_train.reshape(60000,784).astype('float32')

# %%
X_test = X_test.reshape(10000,784).astype('float32')

# %%
X_train /=255

# %%
X_test /=255

# %%
X_train[0]

# %%
n_classes = 10

# %%
Y_train = keras.utils.to_categorical(Y_train, n_classes)

# %%
Y_test = keras.utils.to_categorical(Y_test, n_classes)

# %%
Y_test.shape

# %%
model = Sequential()

# %%
model.add(Dense(64, activation = 'tanh', input_shape=(784,)))

# %%
model.add(Dense(10,activation='softmax'))

# %%
model.summary()

# %%
model.compile(loss='mse',optimizer=SGD(lr=1),metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=1000, epochs=200, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0279 - accuracy: 0.8486 - val_loss: 0.0239 - val_accuracy: 0.8720
# Epoch 2/200
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0233 - accuracy: 0.8706 - val_loss: 0.0207 - val_accuracy: 0.8849
# Epoch 3/200
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0208 - accuracy: 0.8810 - val_loss: 0.0189 - val_accuracy: 0.8923
# Epoch 4/200
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0192 - accuracy: 0.8881 - val_loss: 0.0176 - val_accuracy: 0.8974
# Epoch 5/200
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0180 - accuracy: 0.8925 - val_loss: 0.0167 - val_accuracy: 0.9017
# Epoch 6/200
# 60/60 [==============================] - 1s 8ms/step - loss: 0.0172 - accuracy: 0.8962 - val_loss: 0.0159 - val_accuracy: 0.9046
# Epoch 7/200
# ...
