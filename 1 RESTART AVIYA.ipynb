# %%
my_name = 'MI'+'CAH'
my_name
# Out:
# 'MICAH'

# %%
my_name = 'Avi'+'ya'
my_name
# Out:
# 'Aviya'

# %%
5*56
# Out:
# 280

# %%
0+0
# Out:
# 0

# %%
0-0
# Out:
# 0

# %%
56+4
# Out:
# 60

# %%
5+40
# Out:
# 45

# %%
10+10+20
# Out:
# 40

# %%
2+2+2
# Out:
# 6

# %%
100-100
# Out:
# 0

# %%
100-0
# Out:
# 100

# %%
9+5
# Out:
# 14

# %%
1+5
# Out:
# 6
